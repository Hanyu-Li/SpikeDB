# %%
ls
# Out:
# 3d video.ipynb                      EDR reader.ipynb                    Yev's data.ipynb                    demo2.ipynb
# Analyze XLS-Copy0.ipynb             Insert Input Signal-Copy0.ipynb     beta version.ipynb                  post-demo2.ipynb
# Analyze XLS-Copy1.ipynb             Insert Input Signal.ipynb           bionet_database_utilities.ipynb
# Analyze XLS-Copy2.ipynb             New Dataset Processing-Copy0.ipynb  bionet_database_utilities.py
# Analyze XLS.ipynb                   New Dataset Processing.ipynb        demo.ipynb

# %%
cd ~/src
# Out:
# [Errno 2] No such file or directory: '/Users/hanyuli/src'
# /Users/hanyuli/Envs/SpikeDB/spikedb/notebook

# %%
cd ~/Envs/SpikeDB/spikedb/src/
# Out:
# /Users/hanyuli/Envs/SpikeDB/spikedb/src

# %%
from spikedb import *

# %%
collection = SpikeDB.start()

# %%
root_path = "/Volumes/database_disk/Data/Ban/20131018/"

# %%
result = collection.find()

# %%
for r in result:
    print r
# Out:
# {u'_id': ObjectId('53fb6d6d0122a6043d586076'), u'file_path': u'/Users/hanyuli/flylab_data/m/2014_1_11_001.mat', u'time': datetime.datetime(2014, 1, 11, 15, 36, 22)}
# {u'_id': ObjectId('53fb6d6d0122a6043d586077'), u'file_path': u'/Users/hanyuli/flylab_data/m/2014_1_11_002.mat', u'time': datetime.datetime(2014, 1, 11, 15, 36, 22)}
# {u'_id': ObjectId('53fb6d6d0122a6043d586078'), u'file_path': u'/Users/hanyuli/flylab_data/m/2014_1_11_003.mat', u'time': datetime.datetime(2014, 1, 11, 15, 36, 22)}
# {u'_id': ObjectId('53fb6d6d0122a6043d586079'), u'file_path': u'/Users/hanyuli/flylab_data/m/2014_1_11_004.mat', u'time': datetime.datetime(2014, 1, 11, 15, 36, 24)}
# {u'_id': ObjectId('53fb6d6d0122a6043d58607a'), u'file_path': u'/Users/hanyuli/flylab_data/m/2014_1_11_005.mat', u'time': datetime.datetime(2014, 1, 11, 15, 36, 24)}
# ...
